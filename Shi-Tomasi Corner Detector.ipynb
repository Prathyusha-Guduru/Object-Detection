# %% [markdown]
# # Shi-Tomasi Corner Detector

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('flat_chessboard.png')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img,cmap = 'gray')

# %%
corners = cv2.goodFeaturesToTrack(gray_img,64,0.01,10)
corners = np.int0(corners)

for i in corners:
    x,y = i.ravel()
    cv2.circle(img,(x,y),5,(255,0,0),-1)

plt.imshow(img)

# %%
img = cv2.imread('real_chessboard.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img,cmap = 'gray')

# %%
corners = cv2.goodFeaturesToTrack(gray_img,70,0.01,10)
corners = np.int0(corners)

for i in corners:
    x,y = i.ravel()
    cv2.circle(img,(x,y),3,(255,0,0),-1)
    
plt.imshow(img)
print(corners.shape)
# Out:
# (70, 1, 2)

# %%
img = cv2.imread('shapes.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img,cmap = 'gray')

# %%
corners = cv2.goodFeaturesToTrack(gray_img,10,0.01,10)
corners = np.int0(corners)

for i in corners:
    x,y = i.ravel()
    img[x,y,:] = [255,0,0]
    
plt.imshow(img)
